# %%
import esm4ppe

# %%
eo = esm4ppe.esm4ppeObj('intppdiat','monthly').add_control(triggeropen=True)
# Out:
# Opening static... static opened.
# Control present in zarr store... opening... control opened.

# %%
eo = eo.regionalmean('LME',saveregionalmean=True,verbose=True)
# Out:
# Calculating regional means for control... region: Baltic Sea
# [########################################] | 100% Completed | 4.49 ss
# region: Sea of Okhotsk
# [########################################] | 100% Completed | 3.83 sms
# region: North Sea
# [########################################] | 100% Completed | 3.89 sms
# region: Gulf of Alaska
# [########################################] | 100% Completed | 4.07 sms
# region: Labrador - Newfoundland
# [########################################] | 100% Completed | 3.79 sms
# region: Celtic-Biscay Shelf
# [########################################] | 100% Completed | 3.82 sms
# region: Sea of Japan
# [########################################] | 100% Completed | 3.84 sms
# region: Oyashio Current
# [########################################] | 100% Completed | 4.09 sms
# region: Scotian Shelf
# [########################################] | 100% Completed | 3.84 sms
# region: California Current
# ...

# %%
eo.control.sel(region='Sea of Japan').coarsen(time=12).mean().plot()
