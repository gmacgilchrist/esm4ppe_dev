# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Produce equivalent figures to [Frolicher et al. (2020)](https://bg.copernicus.org/articles/17/2061/2020/)

# %%
from information import *
from plotting import *
from variance import *
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ### Global average PPP (Figure 2)

# %%
savedir = ppeDict['datasavedir']+'/processed/ppp_regionalmeans/'
frequency = 'monthly'
startmonth = 1
maskset = 'global'
filename = '.'.join(['*',frequency,str(startmonth).zfill(2),maskset,'nc'])

region = 'global'
ds = xr.open_mfdataset(savedir+filename).sel(region=region)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 8
#       5 filename = '.'.join(['*',frequency,str(startmonth).zfill(2),maskset,'nc'])
#       7 region = 'global'
# ----> 8 ds = xr.open_mfdataset(savedir+filename).sel(region=region)
#
# File /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/backends/api.py:948, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     945     paths = [os.fspath(p) if isinstance(p, os.PathLike) else p for p in paths]
#     947 if not paths:
# --> 948     raise OSError("no files to open")
#     950 if combine == "nested":
#     951     if isinstance(concat_dim, (str, DataArray)) or concat_dim is None:
#
# OSError: no files to open

# %%
variables = ['tos','phos','o2os','intpp']
colors = {'tos':'black','phos':'red','o2os':'blue','intpp':'green'}

# %%
fig,ax,lines = draw_ppp_regionalmeans(ds[variables],colors=colors)
ax.set_xticks(np.arange(0,121,12))
ax.set_xticklabels(np.arange(0,11))
ax.set_xlabel('Lead time (years)')
ax.set_ylim([-0.2,1])
fig.set_size_inches(8,4)
save_fig(fig,
         'ppp_regionalmeans',
         '-'.join([*variables]),
         '-'.join(filename.split('.')[1:-1]),
         addnames=['froelicher'])

# %% [markdown]
# ### Time horizon (Figure 3)

# %%
savedir = ppeDict['datasavedir']+'/processed/ppp_timehorizon/'
frequency = 'monthly'
smooth = 12
startmonth = 1
filename_cmp = ['*',frequency,str(startmonth).zfill(2)]
if smooth is not None:
    filename_cmp.append('smooth_'+str(smooth).zfill(2))
filename = '.'.join([*filename_cmp,'nc'])

ds = xr.open_mfdataset(savedir+filename)
grid = xr.open_dataset(ppeDict['griddirtmp']+ppeDict['gridfile'])

# %%
variable = 'tos'
fig,ax,im,cbar = draw_globalmap(ds[variable],grid,cname='Predictability Time Horizon (Years)')
im.set_cmap(im.get_cmap().resampled(10))
cbar.set_ticks(np.arange(0,121,12))
cbar.set_ticklabels(np.arange(0,11))
save_fig(fig,
         'ppp_timehorizon',
         variable,
         '-'.join(filename.split('.')[1:-1]),
         addnames=['froelicher'])

# %%
variable = 'phos'
fig,ax,im,cbar = draw_globalmap(ds[variable],grid,cname='Predictability Time Horizon (Years)')
im.set_cmap(im.get_cmap().resampled(10))
cbar.set_ticks(np.arange(0,121,12))
cbar.set_ticklabels(np.arange(0,11))
save_fig(fig,
         'ppp_timehorizon',
         variable,
         '-'.join(filename.split('.')[1:-1]),
         addnames=['froelicher'])

# %%
variable = 'o2os'
fig,ax,im,cbar = draw_globalmap(ds[variable],grid,cname='Predictability Time Horizon (Years)')
im.set_cmap(im.get_cmap().resampled(10))
cbar.set_ticks(np.arange(0,121,12))
cbar.set_ticklabels(np.arange(0,11))
save_fig(fig,
         'ppp_timehorizon',
         variable,
         '-'.join(filename.split('.')[1:-1]),
         addnames=['froelicher'])

# %%
variable = 'intpp'
fig,ax,im,cbar = draw_globalmap(ds[variable],grid,cname='Predictability Time Horizon (Years)')
im.set_cmap(im.get_cmap().resampled(10))
cbar.set_ticks(np.arange(0,121,12))
cbar.set_ticklabels(np.arange(0,11))
save_fig(fig,
         'ppp_timehorizon',
         variable,
         '-'.join(filename.split('.')[1:-1]),
         addnames=['froelicher'])
