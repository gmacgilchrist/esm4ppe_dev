# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Develop procedure for calculating climpred skills for this ensemble

# %%
import climpred as cp
from processing import *
from information import *
from variance import *
import pandas as pd
import cftime

# %%
variable = 'intpp'
frequency = 'monthly'
startmonth = 1
metric = 'acc'
comparison = 'm2m'
reference = 'persistence'

# %%
skill = calc_skill(variable,
                   frequency,
                   startmonth=startmonth,
                   metric=metric,
                   comparison=comparison,
                   reference=reference,
                   save=True,
                   verbose=True)
# Out:
# Calculating acc for intpp
# Start year : 123
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 161
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 185
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 208
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 230
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 269
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 300
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 326
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 359
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# Start year : 381
# Opening member 1
# Opening member 2
# Opening member 3
# Opening member 4
# Opening member 5
# Opening member 6
# Opening member 7
# Opening member 8
# Opening member 9
# Adding control
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/variable.py:1721: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   result = result._stack_once(dims, new_dim)
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/climpred/classes.py:1597: UserWarning: Calculate persistence from lead=1 instead of lead=0 (recommended).
#   warnings.warn(
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/indexing.py:1372: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xarray/core/variable.py:1721: PerformanceWarning: Reshaping is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array.reshape(shape)
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array.reshape(shape)Explictly passing ``limit`` to ``reshape`` will also silence this warning
#     >>> array.reshape(shape, limit='128 MiB')
#   result = result._stack_once(dims, new_dim)
# [####################################### ] | 99% Completed | 37m 36ss
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 40m 39s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 45m 43s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 50m 28s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 55m 36s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 55m 44s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 64m 56s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 65m 29s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 76m 29s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 76m 42s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 79m 21s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 80m 40s
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 15ms
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 25m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 26m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 29m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 29m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 47m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 49m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [####################################### ] | 99% Completed | 2hr 52m
# /nbhome/gam/miniconda3/envs/climpred_clean/lib/python3.10/site-packages/xskillscore/core/np_deterministic.py:309: RuntimeWarning: divide by zero encountered in divide
#   r = r_num / r_den
# [########################################] | 100% Completed | 2hr 53m

# %%
skill['intpp'].isel(lead=0).plot()
